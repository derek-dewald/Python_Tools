# %%
# Conda and Streamlit Dash Do not mesh well.

# %%
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSnwd-zccEOQbpNWdItUG0qXND5rPVFbowZINjugi15TdWgqiy3A8eMRhbmSMBiRhHt1Qsry3E8tKY8/pub?output=csv'
df = pd.read_csv(url)
df
# Out:
#       Program                          Description  \
# 0         API                         Batch Vs API
# 1      Debian                              apt-get
# 2      Debian                                  apt
# 3      Docker                            Run Image
# 4      Docker                Check Open Containers
# ..        ...                                  ...
# 187  Anaconda                   Delete Environment
# 188  Anaconda  Create Environment from Exising Env
# 189  Anaconda         Create Environment from YAML
# 190  Anaconda          List Available Environments
# 191    Python          Add New Path to System Path
#
#                                   Command/ Code  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                   docker run -it NAME /bin/sh
# 4                                  docker ps -a
# ..                                          ...
# 187                    conda env remove -n py39
# 188    conda create --name newpy39 --clone py39
# 189  conda env create -f BASE_REQUIREMENTS.yaml
# 190                                  conda list
# 191                       sys.path.append(path)
#
#                                               Comments
# 0    Batch processing is simplier, and more heavily...
# 1    Command-line-centric and might have a steeper ...
# 2    User-friendly and intuitive, providing a simpl...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
#
# [192 rows x 4 columns]
