# %%
import os

def print_tree(start_path='.', max_depth=3, prefix=''):
    for root, dirs, files in os.walk(start_path):
        depth = root[len(start_path):].count(os.sep)
        if depth >= max_depth:
            continue
        indent = '  ' * depth
        print(f"{indent}{os.path.basename(root)}/")
        for f in files:
            print(f"{indent}  {f}")

# Run this from your project root
print_tree('.', max_depth=3)
# Out:
# ./
#   .DS_Store
#   Untitled.ipynb
#   .gitignore
#   history.txt
#   Machine Learning/
#     .DS_Store
#     ML Workbook V2.ipynb
#     SKLearnModels.csv
#     Visualizations.ipynb
#     mlruns/
#     .ipynb_checkpoints/
#       ML Workbook V2-checkpoint.ipynb
#       Visualizations-checkpoint.ipynb
#   EDA/
#     EDA Notebook.ipynb
#     .ipynb_checkpoints/
#       EDA Notebook-checkpoint.ipynb
#   Docker/
#   Streamlit/
#     .DS_Store
#     DataDictionary/
#       .DS_Store
#       requirements.txt
#       MarkdownNotes.py
#       dashboard.py
#       process.py
#       PythonFunctions.py
#       code_dashboard.py
#       Test.ipynb
#       Dashboard_Development.ipynb
#   Archive/
#     .DS_Store
#     ReadMe.md
#     function.csv
#     history.txt
#     ML_Project_Presentation.md
#     BASE_REQUIREMENTS.yaml
#     Processes/
#     DailyEntries/
#       .DS_Store
#     Definitions/
#   images/
#     ActivationFunctions.png
#     confusion_matrix.png
#     bias.png
#     logistic.png
#     Anscombe_Quartet.png
#     .DS_Store
#     Optimizer_Performance.png
#     Kubernetes.png
#     cosine_similiarity.png
#     SVM.png
#     Mnist_Simple_results.png
#     spark.png
#     Consulting_Fees.png
#     X_OR.png
#     SQL_Cheatsheet.png
#     scikit_learn_models.png
#     harmonic_mean.png
#     readme
#     BigO.png
#     ML_AI_Significance_Chart.png
#     Variance_Not_Equal.png
#     BiParte_Graph.png
#     ImpactOutliers.png
#     MultiClass_LogisticReg.png
#     Log_loss.png
#     AI_ML_DL_Visual.png
#     MNist_Results.png
#     Correlation_Visual.png
#     bias1.png
#     ML_Environment.png
#     Optimizers.png
#     DataVsModel.png
#     Boosting_.png
#     Loss_Functions.png
#     Bagging.png
#     Sigmoid.png
#     .ipynb_checkpoints/
#       bias1-checkpoint.png
#       bias-checkpoint.png
#   .devcontainer/
#     devcontainer.json
#   Plotly/
#     Plotly.ipynb
#   Math/
#     Statistics.ipynb
#     .ipynb_checkpoints/
#       Statistics-checkpoint.ipynb
#   PythonGeneral/
#     GeneralWorkbook.ipynb
#     Requests.ipynb
#     .ipynb_checkpoints/
#       GeneralWorkbook-checkpoint.ipynb
#       Requests-checkpoint.ipynb
#   JupyterNotebooks/
#     Daily Workbook.ipynb
#     .DS_Store
#     Untitled.ipynb
#     __init__.py
#     Function Examples.ipynb
#     TEMP.ipynb
#     Helpful Hints.ipynb
#     BC Stats Can Data.ipynb
#     __pycache__/
#       SharedFolder.cpython-312.pyc
#       Connections.cpython-312.pyc
#       Connections.cpython-311.pyc
#     ArchivePyFunctions/
#       FeatureEngineering.py
#       DateFunctions.py
#       Organization.py
#       Connections.py
#       UtilityFunctions.py
#       __init__.py
#       SharedFolder.py
#       Visualization.py
#       EDA.py
#       DFProcessing.py
#       MLPipeline.py
#       SQL.py
#       Validation.py
#     .ipynb_checkpoints/
#       Function Examples-checkpoint.ipynb
#       Daily Workbook-checkpoint.ipynb
#       ML_Development_Notes-checkpoint.py
#       Helpful Hints-checkpoint.ipynb
#       BC Stats Can Data-checkpoint.ipynb
#       TEMP-checkpoint.ipynb
#       Untitled-checkpoint.ipynb
#   Notes/
#     Notes.md
#     Notes.ipynb
#     .ipynb_checkpoints/
#       Notes-checkpoint.ipynb
#   Matplotlib/
#   .ipynb_checkpoints/
#     Daily Workbook-checkpoint.ipynb
#     Untitled-checkpoint.ipynb
#     ReadMe-checkpoint.md
#     MachineLearning-checkpoint.ipynb
#     Visualizations-checkpoint.ipynb
#   CSV Backup Files/
#     ML_Pipeline_Mar-25.csv
#     .DS_Store
#     CodingDDashboard_Mar-25.csv
#     DataDashboardSheet_Apr-25.csv
#     Notes_Apr-25.csv
#     SKLearn Models_Apr-25.csv
#     Mapping Sheet_Mar-25.csv
#     ProcessSheet_Mar-25.csv
#     CodingDDashboard_Apr-25.csv
#     DataDashboardSheet_Mar-25.csv
#     ML_Pipeline_Apr-25.csv
#     ProcessSheet_Apr-25.csv
#     Mapping Sheet_Apr-25.csv
#     SKLearn Models_Mar-25.csv
#     Notes_Mar-25.csv
#     downloaded_py_files/
#       .DS_Store
#   .git/
#     .DS_Store
#     ORIG_HEAD
#     config
#     HEAD
#     description
#     index
#     packed-refs
#     COMMIT_EDITMSG
#     FETCH_HEAD
#     objects/
#     info/
#       exclude
#     lost-found/
#     logs/
#       HEAD
#     hooks/
#       commit-msg.sample
#       pre-rebase.sample
#       pre-commit.sample
#       applypatch-msg.sample
#       fsmonitor-watchman.sample
#       pre-receive.sample
#       prepare-commit-msg.sample
#       post-update.sample
#       pre-merge-commit.sample
#       pre-applypatch.sample
#       pre-push.sample
#       update.sample
#       push-to-checkout.sample
#     refs/
#       stash
#   d_py_functions/
#     .DS_Store
#     FeatureEngineering.py
#     DateFunctions.py
#     Organization.py
#     Connections.py
#     UtilityFunctions.py
#     __init__.py
#     SharedFolder.py
#     Visualization.py
#     EDA.py
#     DFProcessing.py
#     MLPipeline.py
#     SQL.py
#     Validation.py
#     Archive/
#       Definitions_.py
#       temp_.py
#       ImagePixelation_.py
#       Connections_.py
#     __pycache__/
#       EDA.cpython-311.pyc
#       SharedFolder.cpython-311.pyc
#       EDA.cpython-312.pyc
#       SharedFolder.cpython-312.pyc
#       D_Organizing.cpython-312.pyc
#       D_Organizing.cpython-311.pyc
#       MLPipeline.cpython-312.pyc
#       MLPipeline.cpython-311.pyc
#       DFProcessing.cpython-312.pyc
#       Visualization.cpython-312.pyc
#       DF_Functions.cpython-312.pyc
#       Organization.cpython-312.pyc
#       DF_Functions.cpython-311.pyc
#       Organization.cpython-311.pyc
#       StaticValues.cpython-312.pyc
#       temp.cpython-311.pyc
#       Validation.cpython-312.pyc
#       FeatureEngineering.cpython-311.pyc
#       DateFunctions.cpython-312.pyc
#       FeatureEngineering.cpython-312.pyc
#       Connections.cpython-312.pyc
#       __init__.cpython-312.pyc
#       Definitions.cpython-312.pyc
#       Connections.cpython-311.pyc
#       __init__.cpython-311.pyc
#       SHARED_FOLDER_MANAGEMENT.cpython-311.pyc
#       Definitions.cpython-311.pyc
#     .ipynb_checkpoints/
#       static_lists-checkpoint.py
#       SharedFolder-checkpoint.py
#   Data/
#     Datasets.ipynb
#     .ipynb_checkpoints/
#       Datasets-checkpoint.ipynb
#   Time-Series-Analysis-with-Python-Cookbook-Second-Edition/
#     .DS_Store
#     LICENSE
#     test.csv
#     TimeSeriesWorkBook.ipynb
#     README.md
#     data.pkl
#     datasets/
#       .DS_Store
#     code/
#       .DS_Store
#     .ipynb_checkpoints/
#       TimeSeriesWorkBook-checkpoint.ipynb
#     .git/
#       .DS_Store
#       config
#       HEAD
#       description
#       index
#       packed-refs
#   Spark/
#     Spark.ipynb
#     .ipynb_checkpoints/
#       Spark-checkpoint.ipynb
#   SQL/
#     SQL.ipynb
#     .ipynb_checkpoints/
#       SQL-checkpoint.ipynb

# %%
os.path.dirname(os.getcwd())
# Out:
# '/Users/derekdewald/Documents/Python'

# %%
os.path.join(os.path.dirname(os.getcwd()), '..', '..', 'd_py_functions')
# Out:
# '/Users/derekdewald/Documents/Python/../../d_py_functions'

# %%
print(sys.path)
# Out:
# ['/Users/derekdewald/anaconda3/envs/BaseRequirements/lib/python312.zip', '/Users/derekdewald/anaconda3/envs/BaseRequirements/lib/python3.12', '/Users/derekdewald/anaconda3/envs/BaseRequirements/lib/python3.12/lib-dynload', '', '/Users/derekdewald/anaconda3/envs/BaseRequirements/lib/python3.12/site-packages', '/Users/derekdewald/d_py_functions']
