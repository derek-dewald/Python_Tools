# %%
import pandas as pd
import numpy as np
from sklearn import datasets

import sys
sys.path.append("/Users/derekdewald/Documents/Python/Github_Repo/d_py_functions")

# Load the diabetes dataset
diabetes = datasets.load_diabetes()
df = pd.DataFrame(diabetes['data'],columns=diabetes['feature_names'])
df = pd.concat([df,pd.DataFrame(diabetes['target'],columns=['Target'])],axis=1)
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  Target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
from EDA import Heatmap

Heatmap(df)

# %%
plot_histograms(df)

# %%
plot_scatter_matrix(df)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import math

# %%
calculate_vif(df)
# Out:
#    Feature        VIF                        Assessement  Action
# 0      age   1.217315  Low to Moderate Multicollinearity    Pass
# 1      sex   1.283075  Low to Moderate Multicollinearity    Pass
# 2      bmi   1.532949  Low to Moderate Multicollinearity    Pass
# 3       bp   1.468583  Low to Moderate Multicollinearity    Pass
# 4       s1  59.257108           Severe Multicollinearity  Review
# 5       s2  39.213144           Severe Multicollinearity  Review
# 6       s3  15.403044           Severe Multicollinearity  Review
# 7       s4   8.893714             High Multicollinearity  Review
# 8       s5  10.125073           Severe Multicollinearity  Review
# 9       s6   1.485021  Low to Moderate Multicollinearity    Pass
# 10  Target   1.118065  Low to Moderate Multicollinearity    Pass

# %%
analyze_distribution(df)

# %%
ColumnPartitioner(df,'bmi')
# Out:
#      Partition 1  Partition 2  Partition 3  Partition 4  Partition 5  \
# bmi    -0.090275    -0.057941    -0.039618    -0.029918    -0.018062
#
#      Partition 6  Partition 7  Partition 8  Partition 9  Partition 10
# bmi    -0.006206     0.006728     0.023973     0.045529      0.070319

# %%
ColumnPartitioner(df,'bmi',return_value='list_index')
# Out:
# [0, 45, 90, 135, 180, 225, 270, 315, 360, 405]

# %%
ColumnPartitioner(df,'bmi',return_value='list_value')
# Out:
# [-0.09027529589850945,
#  -0.05794093368208547,
#  -0.039618128426111884,
#  -0.029917819761184662,
#  -0.018061886948495892,
#  -0.006205954135807083,
#  0.006727790750762504,
#  0.023972783932855315,
#  0.045529025410471304,
#  0.07031870310972965]

# %%
ColumnPartitioner(df,'bmi',return_value='agg_value')
# Out:
#                                 VALUE
# Total Balance in Partion 1  -3.131159
# Total Balance in Partion 2  -2.175139
# Total Balance in Partion 3  -1.544619
# Total Balance in Partion 4  -1.043437
# Total Balance in Partion 5  -0.504531
# Total Balance in Partion 6  -0.000115
# Total Balance in Partion 7   0.663818
# Total Balance in Partion 8   1.569180
# Total Balance in Partion 9   2.582323
# Total Balance in Partion 10  3.583679

# %%
ColumnPartitioner(df,'bmi',return_value='position_value')
# Out:
#                    bmi  AGGREGATE_VALUE
# Partition 1  -0.090275        -3.131159
# Partition 2  -0.057941        -2.175139
# Partition 3  -0.039618        -1.544619
# Partition 4  -0.029918        -1.043437
# Partition 5  -0.018062        -0.504531
# Partition 6  -0.006206        -0.000115
# Partition 7   0.006728         0.663818
# Partition 8   0.023973         1.569180
# Partition 9   0.045529         2.582323
# Partition 10  0.070319         3.583679
