# %%
import os
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'untitled.chat',
#  'pyproject.toml',
#  '.venv',
#  '.ipynb_checkpoints',
#  'poetry.lock']

# %%
os.getcwd()
# Out:
# '/Users/derekdewald/Documents/Python/Github_Repo/Project Folder/test'

# %%
import os
os.listdir('/Users/derekdewald/Documents/Python/Github_Repo/JupyterNotebooks')
# Out:
# ['Skills Network Editor2.pdf',
#  'Reference Notebooks',
#  'ML_MODELS_IN_AZURE_CLASSIFICATION.ipynb',
#  'Skills Network Editor.pdf',
#  'Untitled1.ipynb',
#  'To Do List.ipynb',
#  '.DS_Store',
#  'D.yml',
#  'Process Checklist Function.ipynb',
#  'Archive',
#  'Untitled.ipynb',
#  'object_manual_published.xlsx',
#  'shared_folder.py',
#  'Daily Sheet.ipynb',
#  '__init__.py',
#  'Untitled2.ipynb',
#  '__pycache__',
#  'ML_MODELS_IN_AZURE_REGRESSIOn.ipynb',
#  'mlruns',
#  'Function Example.ipynb',
#  'ArchivePyFunctions',
#  'test.xlsx',
#  'Daily_Pipeline_v2.ipynb',
#  'penguin_model.pkl',
#  'Example Function Usage.ipynb',
#  '.ipynb_checkpoints',
#  'parameter_list_url.csv',
#  'TF.yml',
#  'Synthetic Member.ipynb',
#  'delete.xlsx',
#  'model_dict.xlsx',
#  'NEW_THING.py']

# %%
import requests

response = requests.post(
    "http://127.0.0.1:11434/api/generate",
    json={
        "model": "llama3.1:8b",
        "prompt": "Explain pandas groupby in one paragraph.",
        "stream": False
    }
)

print(response.json()["response"])
# Out:
# The `groupby` function in the pandas library is used to split a DataFrame into groups based on one or more keys, and then apply aggregation operations (such as mean, sum, etc.) to each group. It allows users to easily summarize and analyze data by grouping similar observations together. For example, if you have a DataFrame of sales data with columns for region, product, and sales amount, you can use `groupby` to calculate the total sales amount for each region or product, making it easier to understand trends and patterns in your data. The resulting groups are represented as a GroupBy object, which can be manipulated further using various methods such as aggregation, filtering, and sorting.
