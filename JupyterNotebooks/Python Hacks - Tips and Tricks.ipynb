# %%
import pandas as pd
import numpy as np

import sys
sys.path.append("/Users/derekdewald/Documents/Python/Github_Repo/d_py_functions")

# %%
from DataSets import FakeBaseballstats,GenerateFakeMemberDF

df = FakeBaseballstats()

# A way to simply add a count of the total instances a particular value has and add it back to a Dataframe without RECORD_COUNT
df.groupby('Player')['Hits'].transform('count')
# Out:
#              Player           Opponent  Hits  Abs  Year
# 0        Roger Dorn     Boston Red Sox     1    3  1990
# 1       Rick Vaughn     Boston Red Sox     1    5  1990
# 2         Lou Brown  Toronto Blue Jays     2    4  1990
# 3     Pedro Cerrano     Montreal Expos     2    3  1990
# 4     Rachel Phelps     Boston Red Sox     0    4  1990
# ...             ...                ...   ...  ...   ...
# 4855    Rick Vaughn     Montreal Expos     0    2  1994
# 4856      Lou Brown     Montreal Expos     1    2  1994
# 4857  Pedro Cerrano   New York Yankees     1    2  1994
# 4858  Rachel Phelps     Montreal Expos     1    3  1994
# 4859    Jake Taylor     Boston Red Sox     1    4  1994
#
# [4860 rows x 5 columns]

# %% [markdown]
# ## Test When Values are Near Equal
