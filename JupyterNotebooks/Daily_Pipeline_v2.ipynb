# %%
## MAKE NOTES ABOUT KNOWLEDGE BASE. 
# SPECIFICALLY IF I PROCESS NOT GENERAL DEFINITION IT WILL BE BROUGHT OVER. 
# General Definition it will only include if already Included

# %%
# Change the Length of the Columns in the Dashboard.
# Filtering Order for Processes and Categorization is not great for anything that isn't a Formal PRocess with Process steps.
# Should be able to add an additional layer, so when there is #NA in orignal columns it still works.

#  Build a process for Specific Types of ML Procesess, Clustering to incorporate additional features into process - Convoluted as normal step.

# %%
import pandas as pd
import numpy as np
import sys

sys.path.append("/Users/derekdewald/Documents/Python/Github_Repo/d_py_functions")

# %%
from daily_etl_folder_mgmt import generate_files_for_streamlit

knowledge_base_df,process_df,consolidated_df = generate_files_for_streamlit()

# %%
consolidated_df['Process'].value_counts()
# Out:
# Process
# Machine Learning Lifecycle    47
# Behavioural Economics         20
# Feature Selection             12
# Communication                 10
# Cardinal Presentation Sins     9
# General Definition             6
# Goal Setting                   6
# Model Selection                6
# Data Collection                5
# Data Preparation               5
# Bias, Fairness, and Ethics     4
# Regularization                 3
# Model Evaluation               2
# Deployment                     1
# Exploratory Data Analysis      1
# Feature Engineering            1
# Hyperparameter Tuning          1
# Model Interpretability         1
# Monitoring                     1
# Organization - Definition      1
# Problem Definition             1
# Training                       1
# Validation                     1
# Name: count, dtype: int64

# %%
consolidated_df[consolidated_df['Process']=='Communication']
# Out:
#            Process Categorization                         Word  \
# 93   Communication   Process Step      Understand Your Message
# 94   Communication   Process Step     Understand Your Audience
# 95   Communication   Process Step     Understand Your Strategy
# 96   Communication   Process Step            Choosing a Medium
# 97   Communication   Process Step      Understand Your Visuals
# 98   Communication   Process Step            Message Spareness
# 99   Communication   Process Step       Re-enforce the Message
# 100  Communication   Process Step  Cardinal Communication Sins
# 101  Communication   Process Step         General Expectations
# 102  Communication   Process Step       Measuing Effectiveness
#
#                                             Definition
# 93
# 94
# 95   Beyond understanding Your Message, you need to...
# 96   While not always give a choice, it is importan...
# 97
# 98   Utilize a less is more approach, whether that ...
# 99
# 100
# 101
# 102  How can one measure how effective/ineffective ...

# %%
consolidated_df[consolidated_df['Process']=='Machine Learning Lifecycle']
# Out:
#                         Process              Categorization  \
# 17   Machine Learning Lifecycle                     Process
# 46   Machine Learning Lifecycle                Process Step
# 112  Machine Learning Lifecycle                Goal Setting
# 113  Machine Learning Lifecycle                Goal Setting
# 114  Machine Learning Lifecycle                Goal Setting
# 115  Machine Learning Lifecycle                Goal Setting
# 116  Machine Learning Lifecycle                Goal Setting
# 47   Machine Learning Lifecycle                Process Step
# 48   Machine Learning Lifecycle                Process Step
# 126  Machine Learning Lifecycle             Data Collection
# 127  Machine Learning Lifecycle             Data Collection
# 128  Machine Learning Lifecycle             Data Collection
# 129  Machine Learning Lifecycle             Data Collection
# 49   Machine Learning Lifecycle                Process Step
# 122  Machine Learning Lifecycle            Data Preparation
# 50   Machine Learning Lifecycle                Process Step
# 51   Machine Learning Lifecycle                Process Step
# 52   Machine Learning Lifecycle                Process Step
# 134  Machine Learning Lifecycle           Feature Selection
# 135  Machine Learning Lifecycle           Feature Selection
# 136  Machine Learning Lifecycle           Feature Selection
# 137  Machine Learning Lifecycle           Feature Selection
# 138  Machine Learning Lifecycle           Feature Selection
# 139  Machine Learning Lifecycle           Feature Selection
# 140  Machine Learning Lifecycle           Feature Selection
# 141  Machine Learning Lifecycle           Feature Selection
# 142  Machine Learning Lifecycle           Feature Selection
# 143  Machine Learning Lifecycle           Feature Selection
# 144  Machine Learning Lifecycle           Feature Selection
# 53   Machine Learning Lifecycle                Process Step
# 120  Machine Learning Lifecycle             Model Selection
# 130  Machine Learning Lifecycle             Model Selection
# 131  Machine Learning Lifecycle             Model Selection
# 132  Machine Learning Lifecycle             Model Selection
# 133  Machine Learning Lifecycle             Model Selection
# 54   Machine Learning Lifecycle                Process Step
# 55   Machine Learning Lifecycle                Process Step
# 56   Machine Learning Lifecycle                Process Step
# 121  Machine Learning Lifecycle            Model Evaluation
# 57   Machine Learning Lifecycle                Process Step
# 58   Machine Learning Lifecycle                Process Step
# 59   Machine Learning Lifecycle                Process Step
# 60   Machine Learning Lifecycle                Process Step
# 61   Machine Learning Lifecycle                Process Step
# 123  Machine Learning Lifecycle  Bias, Fairness, and Ethics
# 124  Machine Learning Lifecycle  Bias, Fairness, and Ethics
# 125  Machine Learning Lifecycle  Bias, Fairness, and Ethics
#
#                                                   Word  \
# 17                                          Definition
# 46                                        Goal Setting
# 112                                           Specific
# 113                                         Measurable
# 114                                         Achievable
# 115                                           Relevant
# 116                                         Time Bound
# 47                                  Problem Definition
# 48                                     Data Collection
# 126                                         Label Data
# 127                      Ensure Sufficient Data Exists
# 128                       Challenges from Missing Data
# 129                                  Who Owns the Data
# 49                                    Data Preparation
# 122                                     Regularization
# 50                           Exploratory Data Analysis
# 51                                 Feature Engineering
# 52                                   Feature Selection
# 134                Explain Feature Practical Relevance
# 135                        Remove Unnecessary Features
# 136                    Understand Feature Correlations
# 137             Document Feature Statistical Relevance
# 138                                     Avoid Ambguity
# 139                               Is a feature Random?
# 140                                   Model Robustness
# 141                 Test Individual Feature Importance
# 142               Reconstruction Error in Autoencoders
# 143  Mutual Information with Latent Cluster Assignment
# 144                         Permutation for Clustering
# 53                                     Model Selection
# 120                                    Define Baseline
# 130                        Document Results and Choice
# 131              Define Validation Approach in Advance
# 132                                Validate no Leakage
# 133                     Validate consistency over time
# 54                                            Training
# 55                               Hyperparameter Tuning
# 56                                    Model Evaluation
# 121                          Test Relative to Baseline
# 57                                          Validation
# 58                              Model Interpretability
# 59                                          Deployment
# 60                                          Monitoring
# 61                          Bias, Fairness, and Ethics
# 123                                Review Demographics
# 124                      Test unitended discrimination
# 125                           Document Fairness Checks
#
#                                             Definition
# 17                                       To Be Defined
# 46   Thought process utilized to establish a clear,...
# 112  Describes what will be accomplished and what s...
# 113  Includes a clear way to track progress or dete...
# 114  Realistic given available time, resources, ski...
# 115  Aligns with broader priorities, such as team o...
# 116  Includes a clear deadline or timeframe for com...
# 47   A Clear, Concise and explicit definition of th...
# 48   Data collection involves identifying, sourcing...
# 126  Ensure that All data is defined, and classifie...
# 127  Ensure that model has sufficient representatio...
# 128  What concessions have we made due to a lack of...
# 129  Who is the Data Steward, and Process owners? A...
# 49   Data preparation focuses on cleaning and struc...
# 122  Explain what this means from a practical appli...
# 50   Foundational step in ensuring the success of a...
# 51   Process of creating new input variables that b...
# 52   Process of identifying and retaining the most ...
# 134  Generate feature importance or explanation out...
# 135  Remove features with high missingness or low v...
# 136  Check for multicollinearity or redundant featu...
# 137  Validate selected features using model or stat...
# 138  Avoid ambiguous features. Is a Banana ripe, wh...
# 139  Careful when something is truly random generat...
# 140  How robust is your model to change and what is...
# 141  Need to understand how much an individual feat...
# 142  Does this feature improve the model’s ability ...
# 143  \nHow strongly is this feature associated with...
# 144  Permutation importance measures the value of a...
# 53   The process of choosing the most appropriate a...
# 120
# 130  Ensure that final selection is documented and ...
# 131  Use cross-validation or a structured validatio...
# 132  Ensure no data leakage between training and va...
# 133  Confirm performance stability across folds or ...
# 54   Process of fitting a machine learning model to...
# 55   Optimizing the configuration settings that con...
# 56   Process of measuring how well a trained model ...
# 121
# 57   Validation is the process of assessing model p...
# 58   Process of explaining how a model makes predic...
# 59   Deployment is the process of integrating the t...
# 60   Ongoing process of tracking model performance ...
# 61   This step examines whether the model produces ...
# 123  Evaluate model performance across key demograp...
# 124  Review sensitive features and proxy variables....
# 125  Document fairness checks and mitigation steps....

# %%
#from daily_etl_folder_mgmt import ETL
#ETL()
# Out:
# python_function_list Saved to /Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/
# python_function_parameters Saved to /Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/

# %%
from objects_automated import object_dict

links = pd.read_csv(object_dict['csv_links']['python_object']['d_links'])
notes = pd.read_csv(object_dict['csv_links']['python_object']['google_notes_csv'])
definitions = pd.read_csv(object_dict['csv_links']['python_object']['google_definition_csv'])
technical_notes = pd.read_csv(object_dict['csv_links']['python_object']['technical_notes'])

# %%
from daily_etl_folder_mgmt import extract_object_dot_py
from objects_automated import object_dict as object_dict_auto
from objects_manual import object_dict as object_dict_man

extract_object_dot_py(object_dict_man,'/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/object_manual_published.xlsx')
extract_object_dot_py(object_dict_auto,'/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/object_auto_published.xlsx')

# %%
from daily_etl_folder_mgmt import generate_objects_automated_py
generate_objects_automated_py()

# %%
consolidated_xlsx = '/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/consolidated_dataset.xlsx'
consolidated_df = pd.read_excel(consolidated_xlsx)

# %%
consolidated_df[consolidated_df['Process']=='Algorithm Classification']
# Out:
#                       Process Categorization                      Word  \
# 120  Algorithm Classification     Definition         Anomaly Detection
# 121  Algorithm Classification     Definition            Classification
# 122  Algorithm Classification     Definition                Clustering
# 123  Algorithm Classification     Definition                Regression
# 124  Algorithm Classification     Definition  Ranking / Recommendation
# 125  Algorithm Classification     Definition        Density Estimation
# 126  Algorithm Classification     Definition  Dimensionality Reduction
# 127  Algorithm Classification     Definition         Feature Selection
# 128  Algorithm Classification     Definition    Feature Transformation
# 129  Algorithm Classification     Definition     Information Retrieval
# 130  Algorithm Classification     Definition   Time Series Forecasting
# 131  Algorithm Classification     Definition         Generative Models
# 132  Algorithm Classification     Definition    Reinforcement Learning
# 133  Algorithm Classification     Definition              Optimization
# 134  Algorithm Classification     Definition          Graph Algorithms
# 135  Algorithm Classification     Definition                Prediction
#
#                                             Definition     Location
# 120  Algorithm which designed to identify observati...  Definitions
# 121  Algorithm which assign observations to one of ...  Definitions
# 122  Algorithm which group observations into cluste...  Definitions
# 123  Algorithm which predict continuous numerical v...  Definitions
# 124  Algorithm which order items or suggest relevan...  Definitions
# 125  Approaches which involve modeling the underlyi...  Definitions
# 126  Algorithm which reduce the number of variables...  Definitions
# 127  Methods that identify and retain a subset of e...  Definitions
# 128  Methods which modify existing features into ne...  Definitions
# 129                                                NaN  Definitions
# 130                                                NaN  Definitions
# 131                                                NaN  Definitions
# 132                                                NaN  Definitions
# 133                                                NaN  Definitions
# 134                                                NaN  Definitions
# 135                                                NaN  Definitions

# %%
from daily_processes import daily_test
daily_test()

# %%
# Generate Python File Including All Dictionaries

from dict_processing import dict_defitions_dot_py
dict_defitions_dot_py()
