# %%
import pandas as pd
import numpy as np
import sys

sys.path.append("/Users/derekdewald/Documents/Python/Github_Repo/d_py_functions")

# %%
# LAUNCH FILE HAS BEEN MOVED TO 
'/Users/derekdewald/Documents/Python/Github_Repo/automated_py_jobs/d_documentation_etl.py
## Daily Shell Job
"/Users/derekdewald/Documents/Python/Daily_Shell_Jobs/daily_shell_job.sh"

## Daily Scheduled Job

## Daily Log
# Out:
# '/Users/derekdewald/Documents/Python/Github_Repo/JupyterNotebooks'
