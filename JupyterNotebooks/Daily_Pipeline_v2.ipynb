# %% [markdown]
# ### Daily Process

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("/Users/derekdewald/Documents/Python/Github_Repo/d_py_functions")

# Update Manual Parameter List
from daily_etl_folder_mgmt import extract_object_dot_py,generate_knowledgebase,extract_consolidated_raw_dataset

'''
Daily Process - There is some cyclicality in it, in that objectes_automated is used to build knowledge_base, but it's requries an updated version of knowledge_base. So run process 

'''

# Import Data
notes_df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSQF2lNc4WPeTRQ_VzWPkqSZp4RODFkbap8AqmolWp5bKoMaslP2oRVVG21x2POu_JcbF1tGRcBgodu/pub?output=csv')
definition_df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQq1-3cTas8DCWBa2NKYhVFXpl8kLaFDohg0zMfNTAU_Fiw6aIFLWfA5zRem4eSaGPa7UiQvkz05loW/pub?output=csv')
manual_object_df = pd.read_excel('/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/object_manual_published.xlsx')

# Generate Knowledge Base
knowledge_base_df = generate_knowledgebase(
    notes_df=notes_df,
    definition_df=definition_df,
    export_location='/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/knowledge_base.xlsx')

# Update object_auto_published.xlsx based on Current Information 


df_dict = {
    'Notes':notes_df,
    'Definitions':definition_df,
    'Knowledge Base':knowledge_base_df,
    'Manual Objects':manual_object_df
}

# Update objects_automated.py
extract_consolidated_raw_dataset(df_dict,True)

# Re-import updated version of object_auto_published.xlsx, object_manual_published.xlsx
# Can't import files until this point or else it will include Historical Information
from objects_automated import object_dict as object_dict_auto
from objects_manual import object_dict as object_dict_man

# Generates Updated Versions of object_auto_published.xlsx, object_manual_published.xlsx based on the .py file. IT DOES NOT CHANGE the .py file
extract_object_dot_py(object_dict_man,'/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/object_manual_published.xlsx')
extract_object_dot_py(object_dict_auto,'/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/object_auto_published.xlsx')



auto_object_df = pd.read_excel('/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/object_auto_published.xlsx')
manual_object_df = pd.read_excel('/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/object_manual_published.xlsx')

knowledge_base_df = generate_knowledgebase(
    notes_df=notes_df,
    definition_df=definition_df,
    export_location='/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/knowledge_base.xlsx')

# Generate Define Processes 
knowledge_base_df[knowledge_base_df['Categorization']=='Process Step'].to_excel('/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/defined_processes.xlsx')

# %%
knowledge_base_df[knowledge_base_df['Categorization']=='Process Step'].to_excel('/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/defined_processes.xlsx')

# %%
knowledge_base_df[knowledge_base_df['Process']=='Data Collection']
# Out:
#             Process Categorization                          Word  \
# 23  Data Collection       Guidance  Challenges from Missing Data
# 25  Data Collection       Guidance            Review Definitions
# 24  Data Collection       Guidance            Who is the Steward
#
#                                            Definition
# 23  What concessions have we made due to a lack of...
# 25  Review Semantic and Functional Definitions, en...
# 24  Who is the Data Steward, are they involved, an...

# %%
# Out:
#                         Process Categorization  \
# 69   Machine Learning Lifecycle   Process Step
# 70   Machine Learning Lifecycle   Process Step
# 145  Machine Learning Lifecycle   Process Step
# 147  Machine Learning Lifecycle   Process Step
# 149  Machine Learning Lifecycle   Process Step
# 151  Machine Learning Lifecycle   Process Step
# 153  Machine Learning Lifecycle   Process Step
# 71   Machine Learning Lifecycle   Process Step
# 72   Machine Learning Lifecycle   Process Step
# 73   Machine Learning Lifecycle   Process Step
# 74   Machine Learning Lifecycle   Process Step
# 75   Machine Learning Lifecycle   Process Step
# 76   Machine Learning Lifecycle   Process Step
# 77   Machine Learning Lifecycle   Process Step
# 78   Machine Learning Lifecycle   Process Step
# 79   Machine Learning Lifecycle   Process Step
# 80   Machine Learning Lifecycle   Process Step
# 81   Machine Learning Lifecycle   Process Step
# 82   Machine Learning Lifecycle   Process Step
# 83   Machine Learning Lifecycle   Process Step
# 84   Machine Learning Lifecycle   Process Step
# 18           Problem Definition   Process Step
# 15           Problem Definition   Process Step
# 14           Problem Definition   Process Step
# 17           Problem Definition   Process Step
# 16           Problem Definition   Process Step
# 49    Problem Solving Framework   Process Step
# 50    Problem Solving Framework   Process Step
# 144   Problem Solving Framework   Process Step
# 146   Problem Solving Framework   Process Step
# 148   Problem Solving Framework   Process Step
# 150   Problem Solving Framework   Process Step
# 152   Problem Solving Framework   Process Step
# 51    Problem Solving Framework   Process Step
# 52    Problem Solving Framework   Process Step
# 53    Problem Solving Framework   Process Step
# 54    Problem Solving Framework   Process Step
# 55    Problem Solving Framework   Process Step
# 56    Problem Solving Framework   Process Step
# 57    Problem Solving Framework   Process Step
# 58    Problem Solving Framework   Process Step
# 59    Problem Solving Framework   Process Step
# 60    Problem Solving Framework   Process Step
# 61    Problem Solving Framework   Process Step
# 62    Problem Solving Framework   Process Step
# 63    Problem Solving Framework   Process Step
# 64    Problem Solving Framework   Process Step
# 65    Problem Solving Framework   Process Step
# 66    Problem Solving Framework   Process Step
# 67    Problem Solving Framework   Process Step
#
#                                     Word  \
# 69                          Goal Setting
# 70                    Problem Definition
# 145                   Problem Definition
# 147                   Problem Definition
# 149                   Problem Definition
# 151                   Problem Definition
# 153                   Problem Definition
# 71                       Data Collection
# 72                      Data Preparation
# 73             Exploratory Data Analysis
# 74                   Feature Engineering
# 75                     Feature Selection
# 76                       Model Selection
# 77                              Training
# 78                 Hyperparameter Tuning
# 79                      Model Evaluation
# 80                            Validation
# 81                Model Interpretability
# 82                            Deployment
# 83                            Monitoring
# 84            Bias, Fairness, and Ethics
# 18      Baseline Metrics (Current State)
# 15                Current State Analysis
# 14                 Desired State Metrics
# 17                   Historical Overview
# 16                 Root Cause Assessment
# 49                          Goal Setting
# 50                    Problem Definition
# 144                   Problem Definition
# 146                   Problem Definition
# 148                   Problem Definition
# 150                   Problem Definition
# 152                   Problem Definition
# 51              Current State Assessment
# 52                       Data Collection
# 53                   Root Cause Analysis
# 54              Research and Exploration
# 55                     Option Generation
# 56                       Solution Design
# 57                Feasibility Assessment
# 58    Prioritization and Decision Making
# 59               Implementation Planning
# 60                             Execution
# 61                Testing and Validation
# 62                            Evaluation
# 63                          Optimization
# 64   Documentation and Knowledge Sharing
# 65                            Monitoring
# 66                Continuous Improvement
# 67          Governance, Risk, and Ethics
#
#                                             Definition
# 69   Thought process utilized to establish a clear,...
# 70   A Clear, Concise and explicit definition of th...
# 145  Desired State Metrics: Describe the target out...
# 147  Current State Analysis: Describes how the proc...
# 149  Root Cause Assessment: Identifies the underlyi...
# 151  Historical Overview: Summarizes what actions, ...
# 153  Baseline Metrics (Current State): Quantify the...
# 71   Data collection involves identifying, sourcing...
# 72   Data preparation focuses on cleaning and struc...
# 73   Foundational step in ensuring the success of a...
# 74   Process of creating new input variables that b...
# 75   Process of identifying and retaining the most ...
# 76                                                 NaN
# 77   Process of fitting a machine learning model to...
# 78   Optimizing the configuration settings that con...
# 79   Process of measuring how well a trained model ...
# 80   Validation is the process of assessing model p...
# 81                                                 NaN
# 82   Deployment is the process of integrating the t...
# 83   Ongoing process of tracking model performance ...
# 84   This step examines whether the model produces ...
# 18   Quantify the current state of the problem usin...
# 15   Describes how the process, system, or situatio...
# 14   Describe the target outcomes or performance le...
# 17   Summarizes what actions, initiatives, or attem...
# 16   Identifies the underlying reasons why the prob...
# 49   Thought process utilized to establish a clear,...
# 50   A Clear, Concise and explicit definition of th...
# 144  Desired State Metrics: Describe the target out...
# 146  Current State Analysis: Describes how the proc...
# 148  Root Cause Assessment: Identifies the underlyi...
# 150  Historical Overview: Summarizes what actions, ...
# 152  Baseline Metrics (Current State): Quantify the...
# 51                                                 NaN
# 52   Data collection involves identifying, sourcing...
# 53                                                 NaN
# 54                                                 NaN
# 55                                                 NaN
# 56                                                 NaN
# 57                                                 NaN
# 58                                                 NaN
# 59                                                 NaN
# 60                                                 NaN
# 61                                                 NaN
# 62                                                 NaN
# 63                                                 NaN
# 64                                                 NaN
# 65   Ongoing process of tracking model performance ...
# 66                                                 NaN
# 67                                                 NaN

# %%
from daily_processes import daily_test
daily_test()

# %%
# Generate Python File Including All Dictionaries

from dict_processing import dict_defitions_dot_py
dict_defitions_dot_py()
