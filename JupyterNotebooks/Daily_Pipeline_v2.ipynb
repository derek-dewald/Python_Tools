# %%
## MAKE NOTES ABOUT KNOWLEDGE BASE. 
# SPECIFICALLY IF I PROCESS NOT GENERAL DEFINITION IT WILL BE BROUGHT OVER. 
# General Definition it will only include if already Included

# %%
# Change the Length of the Columns in the Dashboard.
# Filtering Order for Processes and Categorization is not great for anything that isn't a Formal PRocess with Process steps.
# Should be able to add an additional layer, so when there is #NA in orignal columns it still works.

#  Build a process for Specific Types of ML Procesess, Clustering to incorporate additional features into process - Convoluted as normal step.

# %%
import pandas as pd
import numpy as np
import sys

sys.path.append("/Users/derekdewald/Documents/Python/Github_Repo/d_py_functions")

# %%
object_dict['csv_links']['python_object']['google_definition_csv']
# Out:
# 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQq1-3cTas8DCWBa2NKYhVFXpl8kLaFDohg0zMfNTAU_Fiw6aIFLWfA5zRem4eSaGPa7UiQvkz05loW/pub?output=csv'

# %%
#from daily_etl_folder_mgmt import ETL
#ETL()
# Out:
# python_function_list Saved to /Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/
# python_function_parameters Saved to /Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/

# %%
from objects_automated import object_dict

#links = pd.read_csv(object_dict['csv_links']['python_object']['d_links'])
notes = pd.read_csv(object_dict['csv_links']['python_object']['google_notes_csv'])
definitions = pd.read_csv(object_dict['csv_links']['python_object']['google_definition_csv'])
#technical_notes = pd.read_csv(object_dict['csv_links']['python_object']['technical_notes'])

# %%
from daily_etl_folder_mgmt import generate_files_for_streamlit

knowledge_base_df= generate_files_for_streamlit(
    definition_df=definitions,
    notes_df=notes
)

# %%
knowledge_base_df[
    (knowledge_base_df['Process']=='Machine Learning Lifecycle')&(
        (knowledge_base_df['Categorization']==word)|
        (knowledge_base_df['Word']==word)
)
]
# Out:
#                         Process   Categorization  \
# 789  Machine Learning Lifecycle     Process Step
# 790  Machine Learning Lifecycle  Data Collection
# 791  Machine Learning Lifecycle  Data Collection
# 792  Machine Learning Lifecycle  Data Collection
# 793  Machine Learning Lifecycle  Data Collection
# 794  Machine Learning Lifecycle  Data Collection
# 795  Machine Learning Lifecycle  Data Collection
# 796  Machine Learning Lifecycle  Data Collection
# 797  Machine Learning Lifecycle  Data Collection
# 798  Machine Learning Lifecycle  Data Collection
# 799  Machine Learning Lifecycle  Data Collection
#
#                               Word  \
# 789                Data Collection
# 790        Semantic Classification
# 791          Problem Decomposition
# 792               Variable Mapping
# 793                 Gap Assessment
# 794                     Label Data
# 795  Ensure Sufficient Data Exists
# 796   Challenges from Missing Data
# 797              Who Owns the Data
# 798                Functional Role
# 799                  Semantic Type
#
#                                             Definition          Source
# 789  Data collection involves identifying, sourcing...  Knowledge Base
# 790  Establish a consistent understanding of what i...            LVL1
# 791  Break the analytical problem into the distinct...            LVL1
# 792  Connect the conceptual information requirement...            LVL1
# 793  Evaluate the extent to which the available dat...            LVL1
# 794  Ensure that All data is defined and classified...            LVL1
# 795  Ensure that model has sufficient representatio...            LVL1
# 796  What concessions have we made due to a lack of...            LVL1
# 797  Who is the Data Steward and Process owners? Ar...            LVL1
# 798  Describes how a variable is used within a spec...            LVL1
# 799  Describes the meaning or nature of a variable ...            LVL1

# %%
word = 'Data Collection'
knowledge_base_df[(knowledge_base_df['Process']==word)|(knowledge_base_df['Categorization']==word)]
# Out:
#                         Process   Categorization  \
# 443             Data Collection          Process
# 444             Data Collection         Taxonomy
# 445             Data Collection         Taxonomy
# 446             Data Collection         Taxonomy
# 447             Data Collection         Taxonomy
# 448             Data Collection     Process Step
# 449             Data Collection     Process Step
# 450             Data Collection          Warning
# 451             Data Collection    Consideration
# 452             Data Collection     Process Step
# 453             Data Collection  Functional Role
# 454             Data Collection  Functional Role
# 455             Data Collection  Functional Role
# 456             Data Collection  Functional Role
# 457             Data Collection     Process Step
# 458             Data Collection    Semantic Type
# 459             Data Collection    Semantic Type
# 460             Data Collection    Semantic Type
# 461             Data Collection    Semantic Type
# 462             Data Collection    Semantic Type
# 463             Data Collection    Semantic Type
# 464             Data Collection    Semantic Type
# 465             Data Collection    Semantic Type
# 466             Data Collection    Semantic Type
# 467             Data Collection    Semantic Type
# 468             Data Collection    Semantic Type
# 469             Data Collection    Semantic Type
# 470             Data Collection    Semantic Type
# 471             Data Collection    Semantic Type
# 472             Data Collection    Semantic Type
# 473             Data Collection    Semantic Type
# 790  Machine Learning Lifecycle  Data Collection
# 791  Machine Learning Lifecycle  Data Collection
# 792  Machine Learning Lifecycle  Data Collection
# 793  Machine Learning Lifecycle  Data Collection
# 794  Machine Learning Lifecycle  Data Collection
# 795  Machine Learning Lifecycle  Data Collection
# 796  Machine Learning Lifecycle  Data Collection
# 797  Machine Learning Lifecycle  Data Collection
# 798  Machine Learning Lifecycle  Data Collection
# 799  Machine Learning Lifecycle  Data Collection
#
#                                    Word  \
# 443                          Definition
# 444             Semantic Classification
# 445               Problem Decomposition
# 446                    Variable Mapping
# 447                      Gap Assessment
# 448                          Label Data
# 449       Ensure Sufficient Data Exists
# 450        Challenges from Missing Data
# 451                   Who Owns the Data
# 452                     Functional Role
# 453                      Core Variables
# 454                          Supporting
# 455                         Explanatory
# 456                          Monitoring
# 457                       Semantic Type
# 458                               State
# 459                         Descriptive
# 460                          Diagnostic
# 461                  Diagnostic: Change
# 462                   Diagnostic: Trend
# 463                Diagnostic: Momentum
# 464              Diagnostic: Volatility
# 465                          Structural
# 466                          Contextual
# 467                         Demographic
# 468                          Constraint
# 469                Constraint: Capacity
# 470   Constraint: Stability & Fragility
# 471  Constraint: Access & Configuration
# 472           Constraint: Stress & Load
# 473       Constraint: Time & Commitment
# 790             Semantic Classification
# 791               Problem Decomposition
# 792                    Variable Mapping
# 793                      Gap Assessment
# 794                          Label Data
# 795       Ensure Sufficient Data Exists
# 796        Challenges from Missing Data
# 797                   Who Owns the Data
# 798                     Functional Role
# 799                       Semantic Type
#
#                                             Definition          Source
# 443  Data collection involves identifying, sourcing...  Knowledge Base
# 444  Establish a consistent understanding of what i...  Knowledge Base
# 445  Break the analytical problem into the distinct...  Knowledge Base
# 446  Connect the conceptual information requirement...  Knowledge Base
# 447  Evaluate the extent to which the available dat...  Knowledge Base
# 448  Ensure that All data is defined and classified...  Knowledge Base
# 449  Ensure that model has sufficient representatio...  Knowledge Base
# 450  What concessions have we made due to a lack of...  Knowledge Base
# 451  Who is the Data Steward and Process owners? Ar...  Knowledge Base
# 452  Describes how a variable is used within a spec...  Knowledge Base
# 453  Primary variables that directly shape model ou...            LVL1
# 454  Variables that contribute to model quality but...            LVL1
# 455  Variables used to understand and communicate m...            LVL1
# 456  Variables used to assess model behaviour, stab...            LVL1
# 457  Describes the meaning or nature of a variable ...  Knowledge Base
# 458  Represents the current condition of an entity ...            LVL1
# 459  Represents summarized or smoothed behaviour ov...            LVL1
# 460  Represents how an entity's behaviour changes t...            LVL1
# 461  Measures the difference in a value between two...            LVL1
# 462  Represents the overall direction and pattern o...            LVL1
# 463  Measures acceleration or deceleration in an en...            LVL1
# 464  Measures how variable, irregular, or unpredict...            LVL1
# 465  Represents relatively stable attributes descri...            LVL1
# 466  Represents external or situational factors tha...            LVL1
# 467  Represents relatively stable attributes descri...            LVL1
# 468  Represents factors that restrict or enable the...            LVL1
# 469  Represents fundamental limits on what an entit...            LVL1
# 470  Represents the reliability and resilience of a...            LVL1
# 471  Represents limitations or opportunities create...            LVL1
# 472  Represents sustained pressure that restricts f...            LVL1
# 473  Represents contractual, recurring, or long-ter...            LVL1
# 790  Establish a consistent understanding of what i...            LVL1
# 791  Break the analytical problem into the distinct...            LVL1
# 792  Connect the conceptual information requirement...            LVL1
# 793  Evaluate the extent to which the available dat...            LVL1
# 794  Ensure that All data is defined and classified...            LVL1
# 795  Ensure that model has sufficient representatio...            LVL1
# 796  What concessions have we made due to a lack of...            LVL1
# 797  Who is the Data Steward and Process owners? Ar...            LVL1
# 798  Describes how a variable is used within a spec...            LVL1
# 799  Describes the meaning or nature of a variable ...            LVL1

# %%
from daily_etl_folder_mgmt import extract_object_dot_py
from objects_automated import object_dict as object_dict_auto
from objects_manual import object_dict as object_dict_man

extract_object_dot_py(object_dict_man,'/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/object_manual_published.xlsx')
extract_object_dot_py(object_dict_auto,'/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/object_auto_published.xlsx')

# %%
from daily_etl_folder_mgmt import generate_objects_automated_py
generate_objects_automated_py()

# %%
consolidated_xlsx = '/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/consolidated_dataset.xlsx'
consolidated_df = pd.read_excel(consolidated_xlsx)

# %%
consolidated_df[consolidated_df['Process']=='Algorithm Classification']
# Out:
#                       Process Categorization                      Word  \
# 120  Algorithm Classification     Definition         Anomaly Detection
# 121  Algorithm Classification     Definition            Classification
# 122  Algorithm Classification     Definition                Clustering
# 123  Algorithm Classification     Definition                Regression
# 124  Algorithm Classification     Definition  Ranking / Recommendation
# 125  Algorithm Classification     Definition        Density Estimation
# 126  Algorithm Classification     Definition  Dimensionality Reduction
# 127  Algorithm Classification     Definition         Feature Selection
# 128  Algorithm Classification     Definition    Feature Transformation
# 129  Algorithm Classification     Definition     Information Retrieval
# 130  Algorithm Classification     Definition   Time Series Forecasting
# 131  Algorithm Classification     Definition         Generative Models
# 132  Algorithm Classification     Definition    Reinforcement Learning
# 133  Algorithm Classification     Definition              Optimization
# 134  Algorithm Classification     Definition          Graph Algorithms
# 135  Algorithm Classification     Definition                Prediction
#
#                                             Definition     Location
# 120  Algorithm which designed to identify observati...  Definitions
# 121  Algorithm which assign observations to one of ...  Definitions
# 122  Algorithm which group observations into cluste...  Definitions
# 123  Algorithm which predict continuous numerical v...  Definitions
# 124  Algorithm which order items or suggest relevan...  Definitions
# 125  Approaches which involve modeling the underlyi...  Definitions
# 126  Algorithm which reduce the number of variables...  Definitions
# 127  Methods that identify and retain a subset of e...  Definitions
# 128  Methods which modify existing features into ne...  Definitions
# 129                                                NaN  Definitions
# 130                                                NaN  Definitions
# 131                                                NaN  Definitions
# 132                                                NaN  Definitions
# 133                                                NaN  Definitions
# 134                                                NaN  Definitions
# 135                                                NaN  Definitions

# %%
from daily_processes import daily_test
daily_test()

# %%
# Generate Python File Including All Dictionaries

from dict_processing import dict_defitions_dot_py
dict_defitions_dot_py()
