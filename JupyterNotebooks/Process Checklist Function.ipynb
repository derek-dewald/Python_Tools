# %%
import pandas as pd
import numpy as np
import datetime

import sys
sys.path.append("/Users/derekdewald/Documents/Python/Github_Repo/d_py_functions")

# %%
df = pd.read_csv(links['google_notes_csv'])
df1 = pd.read_csv(links['d_knowledge_base_url'])
df2 = pd.read_csv(links['google_definition_csv'])

# %%
def create_process_checklist(): 
    
    '''
    A Function which combines a number of distict ideas to create the dataset for the Process Checklist, which is Used for the Purpose of creating
    checklists to which I can utilize to help provide guardrails and a framework.

    Final Data set structure [Process Name, Process Stage, Note] ???? 
    
    '''




# ML Project
# Data Definition
# Is this a subprocess of ML.

# DO I have something that already puts these together well?
