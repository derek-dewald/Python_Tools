# %% [markdown]
# ## READ ME FOR THIS

# %%
df_segments = pd.DataFrame({
            "SEGMENT": segments,
            column_name: [f"Decile {x}" for x in range(len(segments))]
        })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 df_segments = pd.DataFrame({
# ----> 2             "SEGMENT": segments,
#       3             column_name: [f"Decile {x}" for x in range(len(segments))]
#       4         })
#
# NameError: name 'segments' is not defined

# %%
import pandas as pd
import numpy as np
import datetime

import sys
sys.path.append("/Users/derekdewald/Documents/Python/Github_Repo/d_py_functions")

# %%
from data_d_strings import template_doc_string_print

template_doc_string_print()
# Out:
#     Definition of Function
#
#     Parameters:
#         List of Parameters
#
#     Returns:
#         Object Type
#
#     date_created:27-Feb-26
#     date_last_modified: 27-Feb-26
#     classification:TBD
#     sub_classification:TBD
#     usage:
#         Example Function Call
