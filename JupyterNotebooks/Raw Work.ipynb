# %%
import pandas as pd
import numpy as np
import sys

sys.path.append("/Users/derekdewald/Documents/Python/Github_Repo/d_py_functions")

# %%
import pandas as pd
import numpy as np
import datetime
import shutil
import os
import ast
import re

from objects_manual import object_dict as object_dict_manual

# %%
links_df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTjXiFjpGgyqWDg9RImj1HR_BeriXs4c5-NSJVwQFn2eRKksitY46oJT0GvVX366LO-m1GM8znXDcBp/pub?gid=469651051&single=true&output=csv')

# %%
knowledge_base_df = pd.read_excel('/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/knowledge_base.xlsx')

# %%
# Out:
# 'Machine Learning Ontology has been developed to support the learning, communication, and practical application of machine learning concepts, from foundational theory to real-world implementation. As the field continues to evolve rapidly in both scope and complexity, a clear and consistent framework is essential for organizing concepts, distinguishing related ideas, and translating theory into practice. The ontology is founded on three core principles and organized into five complementary dimensions, each describing a distinct aspect of machine learning knowledge. Together, these dimensions provide a structured framework for understanding, classifying, and communicating analytical concepts'

# %%
knowledge_base_df[knowledge_base_df['Process']=='ML Model Taxonomy']
# Out:
# Empty DataFrame
# Columns: [Process, Categorization, Word, Definition, Source]
# Index: []

# %%
ml_model_tax_list = knowledge_base_df[knowledge_base_df['Process']=='Machine Learning Ontology']['Word'].tolist()

# %%
py_dict_required_columns = knowledge_base_df[knowledge_base_df['Process']=='Python String Documentation']['Word'].tolist()
py_dict_required_columns
# Out:
# ['Definition',
#  'Parameters',
#  'Returns',
#  'Date Created',
#  'Date Last Modified',
#  'Process',
#  'Categorization',
#  'Usage',
#  'Notes',
#  'Required Functions']

# %%
object_dict['process_reference_list'] = {{
    'Process':"Documentation Taxonomy Categorization",
    'Categorization':'Reference List',
    'Word':"Documentation Taxonomy Process",
    'Definition':"Comprehensive List of all Values utilized in Organizational Taxonomy in the Column Process",
    'publish':1,
    'python_object':{process_list}
    }}

object_dict['cat_reference_list'] = {{
    'Process':"Documentation Taxonomy Categorization",
    'Categorization':'Reference List',
    'Word':"Documentation Taxonomy Categorization",
    'Definition':"Comprehensive List of all Values utilized in Organizational Taxonomy in the Column Categorization",
    'publish':1,
    'python_object':{cat_list}
    }}

object_dict['algo_class_ref_list'] = {{
    'Process':"Algorithm Categorization",
    'Categorization':'Reference List',
    'Word':"Algorithm Categorization Reference List",
    'Definition':"Comprehensive List of all Values utilized in Algorithm Categorization, used to Categorize ML Methods in Algorithm Taxonomy",
    'publish':0,
    'python_object':{algo_class_list}
    }}

object_dict['dot_py_reference_proc'] = {{
    'Process':"Dot Py String Taxonomy Process",
    'Categorization':'Reference List',
    'Word':"Dot Py String Taxonomy Process",
    'Definition':"Comprehensive List of all Values utilized in Organizational Taxonomy in the Column Process",
    'publish':1,
    'python_object':{dot_py_proc}
    }}

object_dict['dot_py_reference_cat'] = {{
    'Process':"Dot Py String Taxonomy Categorization",
    'Categorization':'Reference List',
    'Word':"Dot Py String Taxonomy Categorization",
    'Definition':"Comprehensive List of all Values utilized in Organizational Taxonomy in the Column Categorization",
    'publish':1,
    'python_object':{dot_py_cat}
    }}
    

        


object_dict['ml_method_list'] = {{
    'Process':"Method",
    'Categorization':'Reference List',
    'Word':"Method",
    'Definition':"List of Current Values for Distinct Types of Methods (While the distinction is subtle, and confusing), methods are of different types and to understand which to use, and when to apply, its important to understand the distinct classification",
    'publish':0,
    'python_object':{method_list}
        }}

object_dict['ml_function_list'] = {{
    'Process':"Function",
    'Categorization':'Reference List',
    'Word':"Function",
    'Definition':"List of Current Values for Functions. These methods refer to ML (not Python) as help to reinforce the nuance, subtly and what explicitly is happening when a ML model is running",
    'publish':0,
    'python_object':{func_list}
        }}

object_dict['ml_lp_list'] = {{
    'Process':"Learning Paradigm",
    'Categorization':'Reference List',
    'Word':"Learning Paradigm",
    'Definition':"List of Current Values for Items in ML Model Taxonomy",
    'publish':0,
    'python_object':{lp_list}
        }}

# %%
knowledge_base_df
# Out:
#                   Process Categorization  \
# 0     Activation Function       Training
# 1     Activation Function       Training
# 2     Activation Function       Training
# 3     Activation Function       Training
# 4     Activation Function       Training
# ...                   ...            ...
# 1677       Wicked Problem  Consideration
# 1678       Wicked Problem  Consideration
# 1679       Wicked Problem  Consideration
# 1680       Wicked Problem  Consideration
# 1681       Wicked Problem  Consideration
#
#                                                    Word  \
# 0                                            Leaky Relu
# 1                                                  Relu
# 2                                               Sigmoid
# 3                                               Softmax
# 4                                                  Tanh
# ...                                                 ...
# 1677                  Every Solution Alters the Problem
# ...

# %%
links_df
# Out:
#                     Definition                    COLUMN Classification  \
# 0                  Definitions     google_definition_csv   Google Sheet
# 1                        Notes          google_notes_csv   Google Sheet
# 2             Words and Quotes         google_word_quote            NaN
# 3             Daily Activities   google_daily_activities   Google Sheet
# 4              Technical Notes           technical_notes   Google Sheet
# 5                Mapping Sheet                   d_links   Google Sheet
# 6             Python Functions         function_list_url        Git Hub
# 7   Python Function Parameters        parameter_list_url        Git Hub
# 8     Folder Table of Contents            folder_toc_url            NaN
# 9           Consolidated Notes      d_knowledge_base_url            NaN
# 10             Process Library                process_cl            NaN
# 11                  Job Search                Job Search   Google Sheet
# ...

# %%
        
    # Generate Information Required to Populate Automated Dot Py. 

    # Generate Lists for Consolidated Dataframe - Process and Categorization
    process_list = consolidated_df[consolidated_df['Process'].notnull()]['Process'].unique().tolist()
    process_list.sort()
    cat_list = consolidated_df[consolidated_df['Categorization'].notnull()]['Categorization'].unique().tolist()
    cat_list.sort()
   
    # Generate Definitions from definition_df
    algo_class_list = definition_df[(definition_df['Process']=='Algorithm Categorization')&(definition_df['Categorization']!='Process Step')]['Word'].unique().tolist()
    algo_class_list.sort()

    # Generate Lists for Dot Py String Dataframe - Process and Categorization
    dot_py_proc = dot_py_df[dot_py_df['Process'].notnull()]['Process'].unique().tolist()
    dot_py_cat = dot_py_df[dot_py_df['Categorization'].notnull()]['Categorization'].unique().tolist()
    
    
    method_list = definition_df[definition_df['Process']=='Method']['Word'].tolist()
    func_list = definition_df[definition_df['Process']=='Function']['Word'].tolist()
    lp_list = definition_df[definition_df['Process']=='Learning Paradigm']['Word'].tolist()
    
    # Generate df of CSV and URL
    csv_link_df = links_df[links_df['CSV'].notnull()]
    url_link_df = links_df[links_df['Link'].notnull()]










generate_objects_automated_py()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 199
#     195
#     196
#     197
#     198
# --> 199 generate_objects_automated_py()
#
# Cell In[26], line 48, in generate_objects_automated_py(links_df, consolidated_df, dot_py_documentation, definition_df, method)
#      44     # Import Data
#      45     if len(links_df)==0:
#      46         links_df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTjXiFjpGgyqWDg9RImj1HR_BeriXs4c5-NSJVwQFn2eRKksitY46oJT0GvVX366LO-m1GM8znXDcBp/pub?gid=469651051&single=true&output=csv')
#      47     if len(consolidated_df)==0:
# ---> 48         consolidated_df = pd.read_excel(consolidated_xlsx)
#      49     if len(dot_py_documentation)==0:
#      50         dot_py_df = pd.read_csv(dot_py_csv)
#      51     if len(definition_df)==0:
#
# ...

# %%
import pandas as pd
import numpy as np
import datetime

import sys
sys.path.append("/Users/derekdewald/Documents/Python/Github_Repo/d_py_functions")

# %%
today = datetime.datetime.now().strftime('%d-%b-%y')

object_dict['template_doc_string'] = {
    'Process':"Organziation",
    'Categorization':'Reference String',
    'Word':"template_doc_string",
    'Definition':"Default Structure for Python Doc Strings",
    'publish':0,
    'python_object':f'''

    Definition:
        Definition of Function

    Parameters:
        List of Parameters

    Returns:
        Object Type

    date_created:{today}
    date_last_modified: {today}
    classification:TBD
    sub_classification:TBD
    usage:
        Example Function Call
'''
}

# %%
print(inspect.getsource(create_blank_function_doc_string))
# Out:
# def create_blank_function_doc_string(df=None):
#
#     '''
#     Definition:
#         Function which generates Default Documentation for Python Function Documentaiton in consistent format.
#     Parameters:
#         df(dataframe): Knowledge base Dataframe. If None it will pull from either Local or Git Hub.
#     Returns:
#         str
#     Date Created:
#         28-Aug-26
#     Date Last Modified:
#         28-Aug-26
#     Process:
#         TBD
#     Categorization:
#         TBD
#     Usage:
#         create_blank_function_doc_string()
#     Notes:
#         None
#     Required Functions:
#         None
#
#
#     '''
#     if df ==None:
#         try:
#             df = pd.read_excel('/Users/derekdewald/Documents/Python/Github_Repo/Streamlit/Data/knowledge_base.xlsx')
#         except:
#             df = pd.read_excel("https://raw.githubusercontent.com/derek-dewald/Python_Tools/main/Streamlit/Data/knowledge_base.xlsx")
#
# ...

# %%
import inspect
inspect(create_blank_function_doc_string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 import inspect
# ----> 2 inspect(create_blank_function_doc_string)
#
# TypeError: 'module' object is not callable

# %%
df = create_blank_function_doc_string()
# Out:
# Definition:
#     TBD
# Parameters:
#     TBD
# Returns:
#     TBD
# Date Created:
#     28-Aug-26
# Date Last Modified:
#     28-Aug-26
# Process:
#     TBD
# Categorization:
#     TBD
# Usage:
#     TBD
# Notes:
#     None
# Required Functions:
#     None

# %%
def gpt_question(list_,word_list=None):

    for word in list_:
        if not word_list:
            word_list = word
        else:
            word_list += f', {word}'
    text = f"""For the following words, can you please provide me for each word a definition which is 4-5 sentences highlighting the definition,\nits origin, its importance and application. If the word is a ML Model, can you also please define the following in point form,\ntype of ML learning, type of ML problem, size of data set it works best on, and anything else which might be appropriate.\nUnique Words: {word_list}
    """

    print(text)

# %% [markdown]
# ## Document Pages:
# # How I document things
#
# # Machine Learning Code/ Projects
# # Data Pipelines
# # Career.
# # Investing Guidelines
#
#
#
# # Data Validation Process
# # Data Exploration Process
# # Synthetic Member Dataset
# # Clustering ALog
#
# # Data Dictionary
# # Create LLM which can Answer Questions on my computer.
# # Create LLM which is distributed to other computer.

# %%
How can we effectively seek clarification on projects where ambiguity exists, how to escalate in instances where appropriate consideration has not been given or resources not ascribed or allocated. Example Questions who made this decision. Where is the supporting documentation, where decisions are made without appropriate inclusion, what are the repercussions and as a organization how do we prevent this from recoccuring..

# %%
######################################
# Action Add DQ Item.
# Add Read Me, which Explanation of process and Definitions of all Categorizations.
# DQ Validation Component
# Question I need to ask Myself.
######################################

Migrate Away from @Shaw.ca

Loss - And all ways to measure
Optimization - and all ways to measure
Activation - And All Activation Functions.
How to select and use layers.
Metrics - Measure Model Performance
Cross Entropy. Binary and Categorical.

Design And Optimize Models
Automate Tasks 
Drive Innovation

# Establish Process to Set up a New Environment for Every Project. Use Poetry.


What did I learn from AWS.
WHat did I learn from Integration.

Goal | Measure of Success | Benefits | Challenges | Activities - Align to work log
RASCI = Understand how to reference discussion , integrate (Practically, Friendly, Realisitically) 
My Focus| Responsibility| Motivation | Clarification Required | 

- Training Doesn’t start (Loss doesn’t decrease)
- As you can literally train any data, there is something wrong if this occurs. Data Structure, Optimizer, Initial Weight, Learning Rate, Batch Size.
- Model Doesnt Beat Baseline
- Model Structure
- Can’t Severly Overfit despite trying.
- Increase Model Complexity and Size.
- If model is too complex, it can learn things that don’t exist, 
- L1 L2 Weight decay
Read Me? ?
WHAT IS THE PROCESS That this should be representing.


Speak, LORD, for Your servant is listening” (1 Samuel 3:9).
Indifference will keep in and ruin your life.
Unconfessed Sin follows you, and effects more than you.

# %%
df[df['PRIMARY_ACTIVITY']==0][cols].groupby(columns).agg(
    ABS_TRAN_VAL = ('ABS_TRAN_AMT','sum'),
    NET_TRAN_VAL = ('TRANAMT','sum'),
    TXN_VOL = ('ABS_TRAN_AMT','count')
).reset_index()
